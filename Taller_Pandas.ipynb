# %% [markdown]
# *IMPORTAR LA LIBRERIA*

# %% [markdown]
# ##TRAER EL ARCHIVO DE CSV

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_csv = pd.read_csv("C:\\Users\\juan1\\Downloads\\dataset_pandas.csv")

# %%
df_csv
# Out:
#                                                      id    edad  \
# 0                  6c7984c9-270d-4dee-b21e-8460ba65a683    75.0
# 1                  45b54530-317e-4c64-b718-597990ff6fd9    84.0
# 2                  87ef46d9-e9c8-4ba3-8965-5553b48ad2d9     NaN
# 3                  33267565-7115-4bec-9dc1-3e5057412d10    57.0
# 4                  3cddc250-e992-4a30-8097-f1422761b7be    59.0
# ...                                                 ...     ...
# 1000               02568917-9a13-4f6b-ba09-5d664e8069f6    34.0
# 1001               7ddaf233-2a46-429a-b4be-f8ff5917d299    47.0
# 1002               889d5238-aa0c-4717-b841-962d09eeca9c    76.0
# 1003               bacda779-4383-435c-a9d9-c8c8c5b28bd7    57.0
# 1004  Información tomada de: Servicio Nacional de Salud  2023.0
#
#                              email     genero                estado   IMC
# 0         salsobrook0@amazon.co.uk  Masculino               Florida  26.7
# ...

# %% [markdown]
# Hay veces que la ultima fila tiene un resumen o un total de las operaciones de todas las columnas. Podemos usar pandas para quitarlo.

# %%
df_csv = pd.read_csv("C:\\Users\\juan1\\Downloads\\dataset_pandas.csv", skipfooter=1)

df_csv
# Out:
# C:\Users\juan1\AppData\Local\Temp\ipykernel_12612\3362957902.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df_csv = pd.read_csv("C:\\Users\\juan1\\Downloads\\dataset_pandas.csv", skipfooter=1)
#                                         id  edad  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0
# 2     87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0
# ...                                    ...   ...
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0
# 1000  02568917-9a13-4f6b-ba09-5d664e8069f6  34.0
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0
#
# ...
