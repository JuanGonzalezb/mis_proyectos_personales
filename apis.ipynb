# %% [markdown]
# ##**APIs CON PYTHON**

# %% [markdown]
# Consumir la siguiente API:
#
# https://dog.ceo/api/breeds/image/random
# Instrucciones:
# 1. Hacer una petición GET
# 2. Convertir la respuesta a JSON
# 3. Mostrar:
# 4. Status
# 5. URL de la imagen del perro
# 6. Imprimir el resultado en consola

# %% [markdown]
# 1. Importar Librerias

# %%
import requests
import pandas as pd

# %% [markdown]
# 1. Hacer una petición GET

# %%
respuesta = requests.get("https://dog.ceo/api/breeds/image/random")
print(respuesta)
# Out:
# <Response [200]>

# %% [markdown]
# 2. Convertir la respuesta a JSON

# %%
datos = respuesta.json()
print(datos)
# Out:
# {'message': 'https://images.dog.ceo/breeds/dachshund/dachshund-1018409_640.jpg', 'status': 'success'}

# %% [markdown]
# 4. url imagen perro

# %%
print(datos["message"])
# Out:
# https://images.dog.ceo/breeds/dachshund/dachshund-1018409_640.jpg
